# %%
#Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # 2016 Primary Results by County

# %%
#Store cvs file path in a variable
csv_e2016 = "../Resources/primary_results.csv"

#Read CSV into a Pandas dataframe
E2016_df = pd.read_csv(csv_e2016)

#Edit df to include only state, county, party and votes columns
primary2016_df = E2016_df[['state','county','party','votes']].copy()
primary2016_df = primary2016_df.rename(columns={'county':'ga_county'})

#Edit df to only include GA counties
GA2016_df = primary2016_df.loc[(primary2016_df['state']=="Georgia")]

#Set up separate dfs for each party
REP_2016_df = GA2016_df.loc[(GA2016_df['party'] == 'Republican')]
DEM_2016_df = GA2016_df.loc[(GA2016_df['party'] == 'Democrat')]

#Merge dfs to create 1 with both party data
Party_2016_df = pd.merge(REP_2016_df, DEM_2016_df, how = 'outer', on='ga_county')

#Remove unnecessary and rename resulting columns
Party_2016_df = Party_2016_df[['ga_county', 'party_x', 'votes_x', 'party_y', 'votes_y']]
Party_2016_df = Party_2016_df.rename(columns = {'party_x': 'party', 'votes_x':'republican_votes', 'party_y':'party_', 'votes_y':'democrat_votes'})

#Remove "county" and make all capital to match Race data tables
Party_2016_df['ga_county'] = Party_2016_df['ga_county'].str.split(" ",expand = True)
Party_2016_df['ga_county'] = Party_2016_df['ga_county'].str.upper()

##Party_2016_df includes columns indicating party, as well as rows for each (possibly) precint within a county

#Aggregate County Data - total votes per party per county
county_counts = Party_2016_df.groupby(['ga_county'])
county_counts_df = county_counts.sum()

#Add column to show total votes for each county
county_counts_df['total_votes'] = county_counts_df['republican_votes'] + county_counts_df['democrat_votes']
county_counts_df
# Out:
#            republican_votes  democrat_votes  total_votes
# ga_county
# APPLING                6106            3160         9266
# ATKINSON               1868            1250         3118
# BACON                  3316             855         4171
# BAKER                   848            1755         2603
# BALDWIN                8888           18980        27868
# ...                     ...             ...          ...
# WHITFIELD             25196           14215        39411
# WILCOX                 2150            1715         3865
# WILKES                 2976            4215         7191
# WILKINSON              2518            4935         7453
# WORTH                  6718            4250        10968
#
# [159 rows x 3 columns]

# %% [markdown]
# # 2020 Election Results by County

# %%
#Store cvs file path in a variable
csv_e2020 = "../Resources/president_county_candidate.csv"

#Read CSV into a Pandas dataframe
E2020_df = pd.read_csv(csv_e2020)

#Edit df to rename columns
E2020_df = E2020_df.rename(columns={'county':'ga_county'})

#Edit to only include GA counties
GA2020_df = E2020_df.loc[(E2020_df['state']=="Georgia")]

#Create new dfs to show only Democrat and Republican party results
GA_REP_df = GA2020_df.loc[(GA2020_df['party'] == 'REP')]
GA_DEM_df = GA2020_df.loc[(GA2020_df['party'] == 'DEM')]

#Merge DEM/REP Dataframes
GA_2020_df = pd.merge(GA_REP_df, GA_DEM_df, how='outer', on='ga_county')

#Remove and rename resulting columns
GA_party_df = GA_2020_df[['ga_county', 'candidate_x', 'total_votes_x', 'candidate_y', 'total_votes_y']]
GA_party_df = GA_party_df.rename(columns = {'candidate_x': 'republican', 'total_votes_x':'rep_votes', 'candidate_y':'democrat', 'total_votes_y':'dem_votes'})

#Add column with total votes for each county
GA_party_df['total_votes'] = GA_party_df['rep_votes'] + GA_party_df['dem_votes']

#Remove "county" and make all capital to match Race data tables
GA_party_df['ga_county'] = GA_party_df['ga_county'].str.split(" ",expand = True)
GA_party_df['ga_county'] = GA_party_df['ga_county'].str.upper()
GA_party_df
# Out:
#      ga_county    republican  rep_votes   democrat  dem_votes  total_votes
# 0      APPLING  Donald Trump       6526  Joe Biden       1779         8305
# 1     ATKINSON  Donald Trump       2300  Joe Biden        825         3125
# 2        BACON  Donald Trump       4018  Joe Biden        625         4643
# 3        BAKER  Donald Trump        897  Joe Biden        652         1549
# 4      BALDWIN  Donald Trump       8903  Joe Biden       9140        18043
# ..         ...           ...        ...        ...        ...          ...
# 154  WHITFIELD  Donald Trump      25636  Joe Biden      10670        36306
# 155     WILCOX  Donald Trump       2403  Joe Biden        862         3265
# 156     WILKES  Donald Trump       2823  Joe Biden       2160         4983
# 157  WILKINSON  Donald Trump       2664  Joe Biden       2075         4739
# 158      WORTH  Donald Trump       6830  Joe Biden       2395         9225
#
# [159 rows x 6 columns]

# %% [markdown]
# ## Load to Postgres

# %%
#Connect to local database
rds_connection_string = "postgres:postgres@localhost:5432/ga_election_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

#Check for tables
engine.table_names()

#Use pandas to load 2020 DataFrame into database
GA_party_df.to_sql(name='election_2020_ga', con=engine, if_exists='append', index=False)

#Use pandas to load 2016 DataFrame into database
county_counts_df.to_sql(name='primary_2016_ga', con=engine, if_exists='append', index=True)
# Out:
# ['election_2020_ga',
#  'primary_2016_ga',
#  'race_data_2016',
#  'fulton_trump_2020',
#  'fulton_biden_2020',
#  'race_data_2020']

# %% [markdown]
# ## Confirm that data loaded into Postgres

# %%
pd.read_sql_query('select * from primary_2016_ga', con=engine).head()
# Out:
#   ga_county  republican_votes  democrat_votes  total_votes
# 0   APPLING              6106            3160         9266
# 1  ATKINSON              1868            1250         3118
# 2     BACON              3316             855         4171
# 3     BAKER               848            1755         2603
# 4   BALDWIN              8888           18980        27868

# %%
pd.read_sql_query('select * from election_2020_ga', con=engine).head()
# Out:
#   ga_county    republican  rep_votes   democrat  dem_votes  total_votes
# 0   APPLING  Donald Trump       6526  Joe Biden       1779         8305
# 1  ATKINSON  Donald Trump       2300  Joe Biden        825         3125
# 2     BACON  Donald Trump       4018  Joe Biden        625         4643
# 3     BAKER  Donald Trump        897  Joe Biden        652         1549
# 4   BALDWIN  Donald Trump       8903  Joe Biden       9140        18043

# %% [markdown]
# ## Sample Query

# %%
#Import query dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import func

# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
session = Session(engine)

# %%
E2020 = Base.classes.election_2020_ga
Race2020 = Base.classes.race_data_2020

session.query(E2020.ga_county, E2020.total_votes, Race2020.total_voters).all()
# Out:
# [('APPLING', 8305, 11440),
#  ('ATKINSON', 3125, 11440),
#  ('BACON', 4643, 11440),
#  ('BAKER', 1549, 11440),
#  ('BALDWIN', 18043, 11440),
#  ('BANKS', 8727, 11440),
#  ('BARROW', 37257, 11440),
#  ('BARTOW', 49766, 11440),
#  ('BEN', 6502, 11440),
#  ('BERRIEN', 7688, 11440),
#  ('BIBB', 70053, 11440),
#  ('BLECKLEY', 5639, 11440),
#  ('BRANTLEY', 7690, 11440),
#  ('BROOKS', 7050, 11440),
#  ('BRYAN', 20983, 11440),
#  ('BULLOCH', 29629, 11440),
#  ('BURKE', 10609, 11440),
#  ('BUTTS', 11680, 11440),
#  ('CALHOUN', 2183, 11440),
#  ('CAMDEN', 23218, 11440),
#  ('CANDLER', 4402, 11440),
#  ('CARROLL', 53714, 11440),
#  ('CATOOSA', 32099, 11440),
#  ('CHARLTON', 4522, 11440),
#  ('CHATHAM', 131491, 11440),
#  ('CHATTAHOOCHEE', 1547, 11440),
#  ('CHATTOOGA', 9918, 11440),
#  ('CHEROKEE', 142381, 11440),
#  ('CLARKE', 50494, 11440),
#  ('CLAY', 1427, 11440),
#  ('CLAYTON', 111289, 11440),
#  ('CLINCH', 2852, 11440),
#  ('COBB', 387305, 11440),
#  ('COFFEE', 15089, 11440),
#  ('COLQUITT', 15964, 11440),
#  ('COLUMBIA', 79249, 11440),
#  ('COOK', 6959, 11440),
#  ('COWETA', 75711, 11440),
#  ('CRAWFORD', 6043, 11440),
#  ('CRISP', 7973, 11440),
#  ('DADE', 7327, 11440),
#  ('DAWSON', 15884, 11440),
#  ('DECATUR', 11538, 11440),
#  ('DEKALB', 366600, 11440),
#  ('DODGE', 8014, 11440),
#  ('DOOLY', 4070, 11440),
#  ('DOUGHERTY', 35031, 11440),
#  ('DOUGLAS', 68260, 11440),
#  ('EARLY', 5159, 11440),
#  ('ECHOLS', 1423, 11440),
#  ('EFFINGHAM', 31078, 11440),
#  ('ELBERT', 9105, 11440),
#  ('EMANUEL', 9435, 11440),
#  ('EVANS', 4212, 11440),
#  ('FANNIN', 14740, 11440),
#  ('FAYETTE', 71017, 11440),
#  ('FLOYD', 41131, 11440),
#  ('FORSYTH', 127325, 11440),
#  ('FRANKLIN', 10662, 11440),
#  ('FULTON', 518384, 11440),
#  ('GILMER', 16361, 11440),
#  ('GLASCOCK', 1558, 11440),
#  ('GLYNN', 41495, 11440),
#  ('GORDON', 23789, 11440),
#  ('GRADY', 10653, 11440),
#  ('GREENE', 11156, 11440),
#  ('GWINNETT', 408240, 11440),
#  ('HABERSHAM', 20200, 11440),
#  ('HALL', 89201, 11440),
#  ('HANCOCK', 4144, 11440),
#  ('HARALSON', 14123, 11440),
#  ('HARRIS', 19776, 11440),
#  ('HART', 12621, 11440),
#  ('HEARD', 5340, 11440),
#  ('HENRY', 121463, 11440),
#  ('HOUSTON', 73766, 11440),
#  ('IRWIN', 4142, 11440),
#  ('JACKSON', 37139, 11440),
#  ('JASPER', 7583, 11440),
#  ('JEFF', 5723, 11440),
#  ('JEFFERSON', 7598, 11440),
#  ('JENKINS', 3427, 11440),
#  ('JOHNSON', 4072, 11440),
#  ('JONES', 14853, 11440),
#  ('LAMAR', 8945, 11440),
#  ('LANIER', 3528, 11440),
#  ('LAURENS', 22566, 11440),
#  ('LEE', 16565, 11440),
#  ('LIBERTY', 21058, 11440),
#  ('LINCOLN', 4614, 11440),
#  ('LONG', 5561, 11440),
#  ('LOWNDES', 45808, 11440),
#  ('LUMPKIN', 15289, 11440),
#  ('MCDUFFIE', 10337, 11440),
#  ('MCINTOSH', 6628, 11440),
#  ('MACON', 4640, 11440),
#  ('MADISON', 14737, 11440),
#  ('MARION', 3586, 11440),
#  ('MERIWETHER', 10811, 11440),
#  ('MILLER', 2815, 11440),
#  ('MITCHELL', 8930, 11440),
#  ('MONROE', 15444, 11440),
#  ('MONTGOMERY', 3939, 11440),
#  ('MORGAN', 11585, 11440),
#  ('MURRAY', 15245, 11440),
#  ('MUSCOGEE', 79578, 11440),
#  ('NEWTON', 53663, 11440),
#  ('OCONEE', 24757, 11440),
#  ('OGLETHORPE', 8029, 11440),
#  ('PAULDING', 84229, 11440),
#  ('PEACH', 12422, 11440),
#  ('PICKENS', 16883, 11440),
#  ('PIERCE', 8999, 11440),
#  ('PIKE', 10632, 11440),
#  ('POLK', 17247, 11440),
#  ('PULASKI', 4022, 11440),
#  ('PUTNAM', 11739, 11440),
#  ('QUITMAN', 1101, 11440),
#  ('RABUN', 9458, 11440),
#  ('RANDOLPH', 3062, 11440),
#  ('RICHMOND', 85905, 11440),
#  ('ROCKDALE', 44256, 11440),
#  ('SCHLEY', 2262, 11440),
#  ('SCREVEN', 6577, 11440),
#  ('SEMINOLE', 3865, 11440),
#  ('SPALDING', 29841, 11440),
#  ('STEPHENS', 11753, 11440),
#  ('STEWART', 1983, 11440),
#  ('SUMTER', 12050, 11440),
#  ('TALBOT', 3506, 11440),
#  ('TALIAFERRO', 921, 11440),
#  ('TATTNALL', 8114, 11440),
#  ('TAYLOR', 3805, 11440),
#  ('TELFAIR', 4312, 11440),
#  ('TERRELL', 4380, 11440),
#  ('THOMAS', 21662, 11440),
#  ('TIFT', 16106, 11440),
#  ('TOOMBS', 10811, 11440),
#  ('TOWNS', 7934, 11440),
#  ('TREUTLEN', 3053, 11440),
#  ('TROUP', 29721, 11440),
#  ('TURNER', 3759, 11440),
#  ('TWIGGS', 4414, 11440),
#  ('UNION', 15452, 11440),
#  ('UPSON', 12809, 11440),
#  ('WALKER', 28943, 11440),
#  ('WALTON', 50524, 11440),
#  ('WARE', 14076, 11440),
#  ('WARREN', 2635, 11440),
#  ('WASHINGTON', 9393, 11440),
#  ('WAYNE', 12674, 11440),
#  ('WEBSTER', 1387, 11440),
#  ('WHEELER', 2272, 11440),
#  ('WHITE', 14633, 11440),
#  ('WHITFIELD', 36306, 11440),
#  ('WILCOX', 3265, 11440),
#  ('WILKES', 4983, 11440),
#  ('WILKINSON', 4739, 11440),
#  ('WORTH', 9225, 11440),
#  ('APPLING', 8305, 4801),
#  ('ATKINSON', 3125, 4801),
#  ('BACON', 4643, 4801),
#  ('BAKER', 1549, 4801),
#  ('BALDWIN', 18043, 4801),
#  ('BANKS', 8727, 4801),
#  ('BARROW', 37257, 4801),
#  ('BARTOW', 49766, 4801),
#  ('BEN', 6502, 4801),
#  ('BERRIEN', 7688, 4801),
#  ('BIBB', 70053, 4801),
#  ('BLECKLEY', 5639, 4801),
#  ('BRANTLEY', 7690, 4801),
#  ('BROOKS', 7050, 4801),
#  ('BRYAN', 20983, 4801),
#  ('BULLOCH', 29629, 4801),
#  ('BURKE', 10609, 4801),
#  ('BUTTS', 11680, 4801),
#  ('CALHOUN', 2183, 4801),
#  ('CAMDEN', 23218, 4801),
#  ('CANDLER', 4402, 4801),
#  ('CARROLL', 53714, 4801),
#  ('CATOOSA', 32099, 4801),
#  ('CHARLTON', 4522, 4801),
#  ('CHATHAM', 131491, 4801),
#  ('CHATTAHOOCHEE', 1547, 4801),
#  ('CHATTOOGA', 9918, 4801),
#  ('CHEROKEE', 142381, 4801),
#  ('CLARKE', 50494, 4801),
#  ('CLAY', 1427, 4801),
#  ('CLAYTON', 111289, 4801),
#  ('CLINCH', 2852, 4801),
#  ('COBB', 387305, 4801),
#  ('COFFEE', 15089, 4801),
#  ('COLQUITT', 15964, 4801),
#  ('COLUMBIA', 79249, 4801),
#  ('COOK', 6959, 4801),
#  ('COWETA', 75711, 4801),
#  ('CRAWFORD', 6043, 4801),
#  ('CRISP', 7973, 4801),
#  ('DADE', 7327, 4801),
#  ('DAWSON', 15884, 4801),
#  ('DECATUR', 11538, 4801),
#  ('DEKALB', 366600, 4801),
#  ('DODGE', 8014, 4801),
#  ('DOOLY', 4070, 4801),
#  ('DOUGHERTY', 35031, 4801),
#  ('DOUGLAS', 68260, 4801),
#  ('EARLY', 5159, 4801),
#  ('ECHOLS', 1423, 4801),
#  ('EFFINGHAM', 31078, 4801),
#  ('ELBERT', 9105, 4801),
#  ('EMANUEL', 9435, 4801),
#  ('EVANS', 4212, 4801),
#  ('FANNIN', 14740, 4801),
#  ('FAYETTE', 71017, 4801),
#  ('FLOYD', 41131, 4801),
#  ('FORSYTH', 127325, 4801),
#  ('FRANKLIN', 10662, 4801),
#  ('FULTON', 518384, 4801),
#  ('GILMER', 16361, 4801),
#  ('GLASCOCK', 1558, 4801),
#  ('GLYNN', 41495, 4801),
#  ('GORDON', 23789, 4801),
#  ('GRADY', 10653, 4801),
#  ('GREENE', 11156, 4801),
#  ('GWINNETT', 408240, 4801),
#  ('HABERSHAM', 20200, 4801),
#  ('HALL', 89201, 4801),
#  ('HANCOCK', 4144, 4801),
#  ('HARALSON', 14123, 4801),
#  ('HARRIS', 19776, 4801),
#  ('HART', 12621, 4801),
#  ('HEARD', 5340, 4801),
#  ('HENRY', 121463, 4801),
#  ('HOUSTON', 73766, 4801),
#  ('IRWIN', 4142, 4801),
#  ('JACKSON', 37139, 4801),
#  ('JASPER', 7583, 4801),
#  ('JEFF', 5723, 4801),
#  ('JEFFERSON', 7598, 4801),
#  ('JENKINS', 3427, 4801),
#  ('JOHNSON', 4072, 4801),
#  ('JONES', 14853, 4801),
#  ('LAMAR', 8945, 4801),
#  ('LANIER', 3528, 4801),
#  ('LAURENS', 22566, 4801),
#  ('LEE', 16565, 4801),
#  ('LIBERTY', 21058, 4801),
#  ('LINCOLN', 4614, 4801),
#  ('LONG', 5561, 4801),
#  ('LOWNDES', 45808, 4801),
#  ('LUMPKIN', 15289, 4801),
#  ('MCDUFFIE', 10337, 4801),
#  ('MCINTOSH', 6628, 4801),
#  ('MACON', 4640, 4801),
#  ('MADISON', 14737, 4801),
#  ('MARION', 3586, 4801),
#  ('MERIWETHER', 10811, 4801),
#  ('MILLER', 2815, 4801),
#  ('MITCHELL', 8930, 4801),
#  ('MONROE', 15444, 4801),
#  ('MONTGOMERY', 3939, 4801),
#  ('MORGAN', 11585, 4801),
#  ('MURRAY', 15245, 4801),
#  ('MUSCOGEE', 79578, 4801),
#  ('NEWTON', 53663, 4801),
#  ('OCONEE', 24757, 4801),
#  ('OGLETHORPE', 8029, 4801),
#  ('PAULDING', 84229, 4801),
#  ('PEACH', 12422, 4801),
#  ('PICKENS', 16883, 4801),
#  ('PIERCE', 8999, 4801),
#  ('PIKE', 10632, 4801),
#  ('POLK', 17247, 4801),
#  ('PULASKI', 4022, 4801),
#  ('PUTNAM', 11739, 4801),
#  ('QUITMAN', 1101, 4801),
#  ('RABUN', 9458, 4801),
#  ('RANDOLPH', 3062, 4801),
#  ('RICHMOND', 85905, 4801),
#  ('ROCKDALE', 44256, 4801),
#  ('SCHLEY', 2262, 4801),
#  ('SCREVEN', 6577, 4801),
#  ('SEMINOLE', 3865, 4801),
#  ('SPALDING', 29841, 4801),
#  ('STEPHENS', 11753, 4801),
#  ('STEWART', 1983, 4801),
#  ('SUMTER', 12050, 4801),
#  ('TALBOT', 3506, 4801),
#  ('TALIAFERRO', 921, 4801),
#  ('TATTNALL', 8114, 4801),
#  ('TAYLOR', 3805, 4801),
#  ('TELFAIR', 4312, 4801),
#  ('TERRELL', 4380, 4801),
#  ('THOMAS', 21662, 4801),
#  ('TIFT', 16106, 4801),
#  ('TOOMBS', 10811, 4801),
#  ('TOWNS', 7934, 4801),
#  ('TREUTLEN', 3053, 4801),
#  ('TROUP', 29721, 4801),
#  ('TURNER', 3759, 4801),
#  ('TWIGGS', 4414, 4801),
#  ('UNION', 15452, 4801),
#  ('UPSON', 12809, 4801),
#  ('WALKER', 28943, 4801),
#  ('WALTON', 50524, 4801),
#  ('WARE', 14076, 4801),
#  ('WARREN', 2635, 4801),
#  ('WASHINGTON', 9393, 4801),
#  ('WAYNE', 12674, 4801),
#  ('WEBSTER', 1387, 4801),
#  ('WHEELER', 2272, 4801),
#  ('WHITE', 14633, 4801),
#  ('WHITFIELD', 36306, 4801),
#  ('WILCOX', 3265, 4801),
#  ('WILKES', 4983, 4801),
#  ('WILKINSON', 4739, 4801),
#  ('WORTH', 9225, 4801),
#  ('APPLING', 8305, 6726),
#  ('ATKINSON', 3125, 6726),
#  ('BACON', 4643, 6726),
#  ('BAKER', 1549, 6726),
#  ('BALDWIN', 18043, 6726),
#  ('BANKS', 8727, 6726),
#  ('BARROW', 37257, 6726),
#  ('BARTOW', 49766, 6726),
#  ('BEN', 6502, 6726),
#  ('BERRIEN', 7688, 6726),
#  ('BIBB', 70053, 6726),
#  ('BLECKLEY', 5639, 6726),
#  ('BRANTLEY', 7690, 6726),
#  ('BROOKS', 7050, 6726),
#  ('BRYAN', 20983, 6726),
#  ('BULLOCH', 29629, 6726),
#  ('BURKE', 10609, 6726),
#  ('BUTTS', 11680, 6726),
#  ('CALHOUN', 2183, 6726),
#  ('CAMDEN', 23218, 6726),
#  ('CANDLER', 4402, 6726),
#  ('CARROLL', 53714, 6726),
#  ('CATOOSA', 32099, 6726),
#  ('CHARLTON', 4522, 6726),
#  ('CHATHAM', 131491, 6726),
#  ('CHATTAHOOCHEE', 1547, 6726),
#  ('CHATTOOGA', 9918, 6726),
#  ('CHEROKEE', 142381, 6726),
#  ('CLARKE', 50494, 6726),
#  ('CLAY', 1427, 6726),
#  ('CLAYTON', 111289, 6726),
#  ('CLINCH', 2852, 6726),
#  ('COBB', 387305, 6726),
#  ('COFFEE', 15089, 6726),
#  ('COLQUITT', 15964, 6726),
#  ('RANDOLPH', 3062, 2258),
#  ('RICHMOND', 85905, 2258),
#  ('ROCKDALE', 44256, 2258),
#  ('SCHLEY', 2262, 2258),
#  ('SCREVEN', 6577, 2258),
#  ('SEMINOLE', 3865, 2258),
#  ('SPALDING', 29841, 2258),
#  ('STEPHENS', 11753, 2258),
#  ('STEWART', 1983, 2258),
#  ('SUMTER', 12050, 2258),
#  ('TALBOT', 3506, 2258),
#  ('TALIAFERRO', 921, 2258),
#  ('TATTNALL', 8114, 2258),
#  ('TAYLOR', 3805, 2258),
#  ('TELFAIR', 4312, 2258),
#  ('TERRELL', 4380, 2258),
#  ('THOMAS', 21662, 2258),
#  ('TIFT', 16106, 2258),
#  ('TOOMBS', 10811, 2258),
#  ('TOWNS', 7934, 2258),
#  ('TREUTLEN', 3053, 2258),
#  ('TROUP', 29721, 2258),
#  ('TURNER', 3759, 2258),
#  ('TWIGGS', 4414, 2258),
#  ('UNION', 15452, 2258),
#  ('UPSON', 12809, 2258),
#  ('WALKER', 28943, 2258),
#  ('WALTON', 50524, 2258),
#  ('WARE', 14076, 2258),
#  ('WARREN', 2635, 2258),
#  ('WASHINGTON', 9393, 2258),
#  ('WAYNE', 12674, 2258),
#  ('WEBSTER', 1387, 2258),
#  ('WHEELER', 2272, 2258),
#  ('WHITE', 14633, 2258),
#  ('WHITFIELD', 36306, 2258),
#  ('WILCOX', 3265, 2258),
#  ('WILKES', 4983, 2258),
#  ('WILKINSON', 4739, 2258),
#  ('WORTH', 9225, 2258),
#  ('APPLING', 8305, 26742),
#  ('ATKINSON', 3125, 26742),
#  ('BACON', 4643, 26742),
#  ('BAKER', 1549, 26742),
#  ('BALDWIN', 18043, 26742),
#  ('BANKS', 8727, 26742),
#  ('BARROW', 37257, 26742),
#  ('BARTOW', 49766, 26742),
#  ('BEN', 6502, 26742),
#  ('BERRIEN', 7688, 26742),
#  ('BIBB', 70053, 26742),
#  ('BLECKLEY', 5639, 26742),
#  ('BRANTLEY', 7690, 26742),
#  ('BROOKS', 7050, 26742),
#  ('BRYAN', 20983, 26742),
#  ('BULLOCH', 29629, 26742),
#  ('BURKE', 10609, 26742),
#  ('BUTTS', 11680, 26742),
#  ('CALHOUN', 2183, 26742),
#  ('CAMDEN', 23218, 26742),
#  ('CANDLER', 4402, 26742),
#  ('CARROLL', 53714, 26742),
#  ('CATOOSA', 32099, 26742),
#  ('CHARLTON', 4522, 26742),
#  ('CHATHAM', 131491, 26742),
#  ('CHATTAHOOCHEE', 1547, 26742),
#  ('CHATTOOGA', 9918, 26742),
#  ('CHEROKEE', 142381, 26742),
#  ('CLARKE', 50494, 26742),
#  ('CLAY', 1427, 26742),
#  ('CLAYTON', 111289, 26742),
#  ('CLINCH', 2852, 26742),
#  ('COBB', 387305, 26742),
#  ('COFFEE', 15089, 26742),
#  ('COLQUITT', 15964, 26742),
#  ('COLUMBIA', 79249, 26742),
#  ('COOK', 6959, 26742),
#  ('COWETA', 75711, 26742),
#  ('CRAWFORD', 6043, 26742),
#  ('CRISP', 7973, 26742),
#  ('DADE', 7327, 26742),
#  ('DAWSON', 15884, 26742),
#  ('DECATUR', 11538, 26742),
#  ('DEKALB', 366600, 26742),
#  ('DODGE', 8014, 26742),
#  ('DOOLY', 4070, 26742),
#  ('DOUGHERTY', 35031, 26742),
#  ('DOUGLAS', 68260, 26742),
#  ('EARLY', 5159, 26742),
#  ('ECHOLS', 1423, 26742),
#  ('EFFINGHAM', 31078, 26742),
#  ('ELBERT', 9105, 26742),
#  ('EMANUEL', 9435, 26742),
#  ('EVANS', 4212, 26742),
#  ('FANNIN', 14740, 26742),
#  ('FAYETTE', 71017, 26742),
#  ('FLOYD', 41131, 26742),
#  ('FORSYTH', 127325, 26742),
#  ('FRANKLIN', 10662, 26742),
#  ('FULTON', 518384, 26742),
#  ('GILMER', 16361, 26742),
#  ('GLASCOCK', 1558, 26742),
#  ('GLYNN', 41495, 26742),
#  ('GORDON', 23789, 26742),
#  ('GRADY', 10653, 26742),
#  ('GREENE', 11156, 26742),
#  ('GWINNETT', 408240, 26742),
#  ('HABERSHAM', 20200, 26742),
#  ('HALL', 89201, 26742),
#  ('HANCOCK', 4144, 26742),
#  ('HARALSON', 14123, 26742),
#  ('HARRIS', 19776, 26742),
#  ('HART', 12621, 26742),
#  ('HEARD', 5340, 26742),
#  ('HENRY', 121463, 26742),
#  ('HOUSTON', 73766, 26742),
#  ('IRWIN', 4142, 26742),
#  ('JACKSON', 37139, 26742),
#  ('JASPER', 7583, 26742),
#  ('JEFF', 5723, 26742),
#  ('JEFFERSON', 7598, 26742),
#  ('JENKINS', 3427, 26742),
#  ('JOHNSON', 4072, 26742),
#  ('JONES', 14853, 26742),
#  ('LAMAR', 8945, 26742),
#  ('LANIER', 3528, 26742),
#  ('LAURENS', 22566, 26742),
#  ('LEE', 16565, 26742),
#  ('LIBERTY', 21058, 26742),
#  ('LINCOLN', 4614, 26742),
#  ('LONG', 5561, 26742),
#  ('LOWNDES', 45808, 26742),
#  ('LUMPKIN', 15289, 26742),
#  ('MCDUFFIE', 10337, 26742),
#  ('MCINTOSH', 6628, 26742),
#  ('MACON', 4640, 26742),
#  ('MADISON', 14737, 26742),
#  ('MARION', 3586, 26742),
#  ('MERIWETHER', 10811, 26742),
#  ('MILLER', 2815, 26742),
#  ('MITCHELL', 8930, 26742),
#  ('MONROE', 15444, 26742),
#  ('MONTGOMERY', 3939, 26742),
#  ('MORGAN', 11585, 26742),
#  ('MURRAY', 15245, 26742),
#  ('MUSCOGEE', 79578, 26742),
#  ('NEWTON', 53663, 26742),
#  ('OCONEE', 24757, 26742),
#  ('OGLETHORPE', 8029, 26742),
#  ('PAULDING', 84229, 26742),
#  ('PEACH', 12422, 26742),
#  ('PICKENS', 16883, 26742),
#  ('PIERCE', 8999, 26742),
#  ('PIKE', 10632, 26742),
#  ('POLK', 17247, 26742),
#  ('PULASKI', 4022, 26742),
#  ('PUTNAM', 11739, 26742),
#  ('QUITMAN', 1101, 26742),
#  ('RABUN', 9458, 26742),
#  ('RANDOLPH', 3062, 26742),
#  ('RICHMOND', 85905, 26742),
#  ('ROCKDALE', 44256, 26742),
#  ('SCHLEY', 2262, 26742),
#  ('SCREVEN', 6577, 26742),
#  ('SEMINOLE', 3865, 26742),
#  ('SPALDING', 29841, 26742),
#  ('STEPHENS', 11753, 26742),
#  ('STEWART', 1983, 26742),
#  ('SUMTER', 12050, 26742),
#  ('TALBOT', 3506, 26742),
#  ('TALIAFERRO', 921, 26742),
#  ('TATTNALL', 8114, 26742),
#  ('TAYLOR', 3805, 26742),
#  ('TELFAIR', 4312, 26742),
#  ('TERRELL', 4380, 26742),
#  ('THOMAS', 21662, 26742),
#  ('TIFT', 16106, 26742),
#  ('TOOMBS', 10811, 26742),
#  ('TOWNS', 7934, 26742),
#  ('TREUTLEN', 3053, 26742),
#  ('TROUP', 29721, 26742),
#  ('TURNER', 3759, 26742),
#  ('TWIGGS', 4414, 26742),
#  ('UNION', 15452, 26742),
#  ('UPSON', 12809, 26742),
#  ('WALKER', 28943, 26742),
#  ('WALTON', 50524, 26742),
#  ('WARE', 14076, 26742),
#  ('WARREN', 2635, 26742),
#  ('WASHINGTON', 9393, 26742),
#  ('WAYNE', 12674, 26742),
#  ('WEBSTER', 1387, 26742),
#  ('WHEELER', 2272, 26742),
#  ('WHITE', 14633, 26742),
#  ('WHITFIELD', 36306, 26742),
#  ('WILCOX', 3265, 26742),
#  ('WILKES', 4983, 26742),
#  ('WILKINSON', 4739, 26742),
#  ('WORTH', 9225, 26742),
#  ('APPLING', 8305, 12905),
#  ('ATKINSON', 3125, 12905),
#  ('BACON', 4643, 12905),
#  ('BAKER', 1549, 12905),
#  ('BALDWIN', 18043, 12905),
#  ('BANKS', 8727, 12905),
#  ('BARROW', 37257, 12905),
#  ('BARTOW', 49766, 12905),
#  ('BEN', 6502, 12905),
#  ('BERRIEN', 7688, 12905),
#  ('BIBB', 70053, 12905),
#  ('BLECKLEY', 5639, 12905),
#  ('BRANTLEY', 7690, 12905),
#  ('BROOKS', 7050, 12905),
#  ('BRYAN', 20983, 12905),
#  ('BULLOCH', 29629, 12905),
#  ('BURKE', 10609, 12905),
#  ('BUTTS', 11680, 12905),
#  ('CALHOUN', 2183, 12905),
#  ('CAMDEN', 23218, 12905),
#  ('CANDLER', 4402, 12905),
#  ('CARROLL', 53714, 12905),
#  ('CATOOSA', 32099, 12905),
#  ('CHARLTON', 4522, 12905),
#  ('CHATHAM', 131491, 12905),
#  ('CHATTAHOOCHEE', 1547, 12905),
#  ('CHATTOOGA', 9918, 12905),
#  ('CHEROKEE', 142381, 12905),
#  ('CLARKE', 50494, 12905),
#  ('CLAY', 1427, 12905),
#  ('CLAYTON', 111289, 12905),
#  ('CLINCH', 2852, 12905),
#  ('COBB', 387305, 12905),
#  ('COFFEE', 15089, 12905),
#  ('COLQUITT', 15964, 12905),
#  ('COLUMBIA', 79249, 12905),
#  ('COOK', 6959, 12905),
#  ('COWETA', 75711, 12905),
#  ('CRAWFORD', 6043, 12905),
#  ('CRISP', 7973, 12905),
#  ('DADE', 7327, 12905),
#  ('DAWSON', 15884, 12905),
#  ('DECATUR', 11538, 12905),
#  ('DEKALB', 366600, 12905),
#  ('DODGE', 8014, 12905),
#  ('DOOLY', 4070, 12905),
#  ('DOUGHERTY', 35031, 12905),
#  ('DOUGLAS', 68260, 12905),
#  ('EARLY', 5159, 12905),
#  ('ECHOLS', 1423, 12905),
#  ('EFFINGHAM', 31078, 12905),
#  ('ELBERT', 9105, 12905),
#  ('EMANUEL', 9435, 12905),
#  ('EVANS', 4212, 12905),
#  ('FANNIN', 14740, 12905),
#  ('FAYETTE', 71017, 12905),
#  ('FLOYD', 41131, 12905),
#  ('FORSYTH', 127325, 12905),
#  ('FRANKLIN', 10662, 12905),
#  ('FULTON', 518384, 12905),
#  ('GILMER', 16361, 12905),
#  ('GLASCOCK', 1558, 12905),
#  ('GLYNN', 41495, 12905),
#  ('GORDON', 23789, 12905),
#  ('GRADY', 10653, 12905),
#  ('GREENE', 11156, 12905),
#  ('GWINNETT', 408240, 12905),
#  ('HABERSHAM', 20200, 12905),
#  ('HALL', 89201, 12905),
#  ('HANCOCK', 4144, 12905),
#  ('HARALSON', 14123, 12905),
#  ('HARRIS', 19776, 12905),
#  ('HART', 12621, 12905),
#  ('HEARD', 5340, 12905),
#  ('HENRY', 121463, 12905),
#  ('HOUSTON', 73766, 12905),
#  ('IRWIN', 4142, 12905),
#  ('JACKSON', 37139, 12905),
#  ('JASPER', 7583, 12905),
#  ('JEFF', 5723, 12905),
#  ('JEFFERSON', 7598, 12905),
#  ('JENKINS', 3427, 12905),
#  ('JOHNSON', 4072, 12905),
#  ('JONES', 14853, 12905),
#  ('LAMAR', 8945, 12905),
#  ('LANIER', 3528, 12905),
#  ('LAURENS', 22566, 12905),
#  ('LEE', 16565, 12905),
#  ('LIBERTY', 21058, 12905),
#  ('LINCOLN', 4614, 12905),
#  ('LONG', 5561, 12905),
#  ('LOWNDES', 45808, 12905),
#  ('LUMPKIN', 15289, 12905),
#  ('MCDUFFIE', 10337, 12905),
#  ('MCINTOSH', 6628, 12905),
#  ('MACON', 4640, 12905),
#  ('MADISON', 14737, 12905),
#  ('MARION', 3586, 12905),
#  ('MERIWETHER', 10811, 12905),
#  ('MILLER', 2815, 12905),
#  ('MITCHELL', 8930, 12905),
#  ('MONROE', 15444, 12905),
#  ('MONTGOMERY', 3939, 12905),
#  ('MORGAN', 11585, 12905),
#  ('MURRAY', 15245, 12905),
#  ('MUSCOGEE', 79578, 12905),
#  ('NEWTON', 53663, 12905),
#  ('OCONEE', 24757, 12905),
#  ('OGLETHORPE', 8029, 12905),
#  ('PAULDING', 84229, 12905),
#  ('PEACH', 12422, 12905),
#  ('PICKENS', 16883, 12905),
#  ('PIERCE', 8999, 12905),
#  ('PIKE', 10632, 12905),
#  ('POLK', 17247, 12905),
#  ('PULASKI', 4022, 12905),
#  ('PUTNAM', 11739, 12905),
#  ('QUITMAN', 1101, 12905),
#  ('RABUN', 9458, 12905),
#  ('RANDOLPH', 3062, 12905),
#  ('RICHMOND', 85905, 12905),
#  ('ROCKDALE', 44256, 12905),
#  ('SCHLEY', 2262, 12905),
#  ('SCREVEN', 6577, 12905),
#  ('SEMINOLE', 3865, 12905),
#  ('SPALDING', 29841, 12905),
#  ('STEPHENS', 11753, 12905),
#  ('STEWART', 1983, 12905),
#  ('SUMTER', 12050, 12905),
#  ('TALBOT', 3506, 12905),
#  ('TALIAFERRO', 921, 12905),
#  ('TATTNALL', 8114, 12905),
#  ('TAYLOR', 3805, 12905),
#  ('TELFAIR', 4312, 12905),
#  ('TERRELL', 4380, 12905),
#  ('THOMAS', 21662, 12905),
#  ('TIFT', 16106, 12905),
#  ('TOOMBS', 10811, 12905),
#  ('TOWNS', 7934, 12905),
#  ('TREUTLEN', 3053, 12905),
#  ('TROUP', 29721, 12905),
#  ('TURNER', 3759, 12905),
#  ('TWIGGS', 4414, 12905),
#  ('UNION', 15452, 12905),
#  ('UPSON', 12809, 12905),
#  ('WALKER', 28943, 12905),
#  ('WALTON', 50524, 12905),
#  ('WARE', 14076, 12905),
#  ('WARREN', 2635, 12905),
#  ('WASHINGTON', 9393, 12905),
#  ('WAYNE', 12674, 12905),
#  ('WEBSTER', 1387, 12905),
#  ('WHEELER', 2272, 12905),
#  ('WHITE', 14633, 12905),
#  ('WHITFIELD', 36306, 12905),
#  ('WILCOX', 3265, 12905),
#  ('WILKES', 4983, 12905),
#  ('WILKINSON', 4739, 12905),
#  ('WORTH', 9225, 12905),
#  ('APPLING', 8305, 55694),
#  ('ATKINSON', 3125, 55694),
#  ('BACON', 4643, 55694),
#  ('BAKER', 1549, 55694),
#  ('BALDWIN', 18043, 55694),
#  ('BANKS', 8727, 55694),
#  ('BARROW', 37257, 55694),
#  ('BARTOW', 49766, 55694),
#  ('BEN', 6502, 55694),
#  ('BERRIEN', 7688, 55694),
#  ('BIBB', 70053, 55694),
#  ('BLECKLEY', 5639, 55694),
#  ('BRANTLEY', 7690, 55694),
#  ('BROOKS', 7050, 55694),
#  ('BRYAN', 20983, 55694),
#  ('BULLOCH', 29629, 55694),
#  ('BURKE', 10609, 55694),
#  ('BUTTS', 11680, 55694),
#  ('CALHOUN', 2183, 55694),
#  ('CAMDEN', 23218, 55694),
#  ('CANDLER', 4402, 55694),
#  ('CARROLL', 53714, 55694),
#  ('CATOOSA', 32099, 55694),
#  ('CHARLTON', 4522, 55694),
#  ('CHATHAM', 131491, 55694),
#  ('CHATTAHOOCHEE', 1547, 55694),
#  ('CHATTOOGA', 9918, 55694),
#  ('CHEROKEE', 142381, 55694),
#  ('CLARKE', 50494, 55694),
#  ('CLAY', 1427, 55694),
#  ('CLAYTON', 111289, 55694),
#  ('CLINCH', 2852, 55694),
#  ('COBB', 387305, 55694),
#  ('COFFEE', 15089, 55694),
#  ('COLQUITT', 15964, 55694),
#  ('COLUMBIA', 79249, 55694),
#  ('COOK', 6959, 55694),
#  ('COWETA', 75711, 55694),
#  ('CRAWFORD', 6043, 55694),
#  ('CRISP', 7973, 55694),
#  ('DADE', 7327, 55694),
#  ('DAWSON', 15884, 55694),
#  ('DECATUR', 11538, 55694),
#  ('DEKALB', 366600, 55694),
#  ('DODGE', 8014, 55694),
#  ('DOOLY', 4070, 55694),
#  ...]
